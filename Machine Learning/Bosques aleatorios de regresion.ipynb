# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.svm import SVR     
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score

# %%
boston = pd.read_csv('boston.csv', header=1)
boston
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
x= boston.iloc[:, 5:6]
y= boston.iloc[:, 13:14]

# %%
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.2)

# %%
random_forest= RandomForestRegressor(n_estimators= 300, max_depth= 10)

# %%
random_forest.fit(x_train, y_train)
# Out:
# c:\Users\josel\OneDrive\Escritorio\Cursos\Python\Analisis de datos\datos\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(max_depth=10, n_estimators=300)

# %%
y_pred= random_forest.predict(x_test)
y_pred
# Out:
# array([19.23430804, 18.72185732, 18.72902806, 19.02487733, 18.41641778,
#        20.57891659, 20.02590985, 26.53760848, 19.61943359, 18.71519179,
#        16.11537618, 27.75192474, 18.90472946, 17.45837675, 30.56854313,
#        27.89467265, 20.57891659, 18.19165201, 18.69068608, 24.47340024,
#        18.29248   , 18.64674096, 19.63240035, 20.96025507, 21.15013012,
#        36.07635561, 23.84228637, 18.72505923, 39.05326984, 19.12235633,
#        18.55839008, 19.83126612, 33.4681127 , 19.06060883, 10.94681734,
#        21.72007827, 20.40632825, 18.28037583, 23.96641194, 18.61374734,
#        18.69466794, 32.48437306, 12.99020169, 27.8079058 , 18.61774096,
#        19.22960529, 18.72902806, 18.92905946, 15.13248544, 19.33209791,
#        18.66361904, 19.82225938, 20.28719337, 11.97341524, 23.31878293,
#        19.16998028, 19.94433232, 19.13460983, 49.79603889, 34.52259286,
#        30.56854313, 33.77632183, 20.76892733, 28.11743358, 18.6200374 ,
# ...

# %%
random_forest.score(x_train, y_train)
# Out:
# 0.8647140897122728

# %%
df_pred= pd.DataFrame(y_pred, columns=['PREDICCION'])

# Concatena los DataFrames x y df_pred
conjunto_x = pd.concat([x_test, df_pred], axis=1)

x_teste= pd.to_numeric(conjunto_x['RM'])

# %%
x_grid= np.arange(min(x_teste), max(x_teste), 0.1)
x_grid= x_grid.reshape(len(x_grid), 1)
x_grid
# Out:
# array([[4.97],
#        [5.07],
#        [5.17],
#        [5.27],
#        [5.37],
#        [5.47],
#        [5.57],
#        [5.67],
#        [5.77],
#        [5.87],
#        [5.97],
#        [6.07],
#        [6.17],
#        [6.27],
#        [6.37],
#        [6.47],
#        [6.57],
#        [6.67],
#        [6.77],
#        [6.87],
#        [6.97],
#        [7.07],
#        [7.17],
#        [7.27],
#        [7.37],
#        [7.47],
#        [7.57],
#        [7.67],
#        [7.77],
#        [7.87],
#        [7.97],
#        [8.07],
#        [8.17]])

# %%
plt.scatter(x_test, y_test)
plt.plot(x_grid, random_forest.predict(x_grid), c= 'r', linewidth= 3)
plt.show()
# Out:
# c:\Users\josel\OneDrive\Escritorio\Cursos\Python\Analisis de datos\datos\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
x_new= {
    'RM': (1.4 , 2.6 , 8)
}
x_new= pd.DataFrame(x_new)

# %%
x_new_pred= random_forest.predict(x_new)
x_new_pred
# Out:
# array([24.92271667, 24.92271667, 46.06016667])

# %%
mse = mean_squared_error(y_test, y_pred)
print("MSE:", mse)
#un valor de MSE de 56.73 sugiere que las predicciones del modelo tienen una discrepancia 
#promedio relativamente alta con respecto a los valores reales. Idealmente, querríamos minimizar 
#este valor para obtener un mejor rendimiento del modelo.
# Out:
# MSE: 56.729237649077824

# %%
scores = cross_val_score(random_forest.fit(x_train, y_train), x, y, cv=5)  # 5-fold cross-validation
print("Puntuaciones de Validación Cruzada:", scores)
# Out:
# c:\Users\josel\OneDrive\Escritorio\Cursos\Python\Analisis de datos\datos\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\josel\OneDrive\Escritorio\Cursos\Python\Analisis de datos\datos\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\josel\OneDrive\Escritorio\Cursos\Python\Analisis de datos\datos\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# ...

# %%
puntuacion_promedio = scores.mean()
print(f"Puntuación promedio de validación cruzada: {puntuacion_promedio:.4f}")
# Out:
# Puntuación promedio de validación cruzada: 0.0138
