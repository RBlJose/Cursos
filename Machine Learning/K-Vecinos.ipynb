# %%
from sklearn.datasets import load_breast_cancer
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, precision_score, accuracy_score, recall_score, f1_score, roc_auc_score, roc_curve
import matplotlib.pyplot as plt

# %%
Cancer = pd.read_csv('Cancer.csv')
Cancer
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
x= Cancer.iloc[:, 2:33]
y= Cancer.iloc[:, 1:2]

# %%
x_train, x_test, y_train, y_test= train_test_split(x, y , test_size= 0.2)

# %%
KNM= KNeighborsClassifier(n_neighbors= 5, metric= 'minkowski', p= 1) #Dist euclidiana

# %%
KNM.fit(x_train, y_train)
# Out:
# c:\Users\josel\OneDrive\Escritorio\Cursos\Python\Analisis de datos\datos\Lib\site-packages\sklearn\neighbors\_classification.py:238: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier(p=1)

# %%
pred = KNM.predict(x_test)

df_pred = pd.DataFrame(pred, columns=['PREDICCION'])

# Concatena los DataFrames x y df_pred
conjunto_x = pd.concat([y_test, df_pred], axis=1)

conjunto_x['diagnosis'].value_counts(), conjunto_x['PREDICCION'].value_counts()
# Out:
# (diagnosis
#  B    66
#  M    48
#  Name: count, dtype: int64,
#  PREDICCION
#  B    69
#  M    45
#  Name: count, dtype: int64)

# %%
confusion_matrix= confusion_matrix(y_test, pred)
confusion_matrix
# Out:
# array([[64,  2],
#        [ 5, 43]], dtype=int64)

# %%
presicion = precision_score(y_test, pred, pos_label='M')
print(f'{presicion:.4f}')
# Out:
# 0.9556

# %%
exactitud= accuracy_score(y_test, pred)
exactitud
# Out:
# 0.9385964912280702

# %%
sensibilida= recall_score(y_test, pred, pos_label= 'M')
sensibilida
# Out:
# 0.8958333333333334

# %%
f1_score= f1_score(y_test, pred, pos_label= 'M')
f1_score
# Out:
# 0.9247311827956989

# %%
label_encoder = LabelEncoder()
# Ajusta y transforma las etiquetas de clase
y_test= label_encoder.fit_transform(y_test)
y_train= label_encoder.fit_transform(y_train)
pred= label_encoder.fit_transform(pred)
# Out:
# c:\Users\josel\OneDrive\Escritorio\Cursos\Python\Analisis de datos\datos\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\josel\OneDrive\Escritorio\Cursos\Python\Analisis de datos\datos\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
roc_auc= roc_auc_score(y_test, pred)
roc_auc
fpr, tpr, _ = roc_curve(y_test, pred)

# %%
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='b', label=f'AUC = {roc_auc:.4f}')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('Tasa de falsos positivos')
plt.ylabel('Tasa de verdaderos positivos')
plt.title('Curva ROC')
plt.legend()
plt.show()

# %%
# Define tus propios colores como una lista
colors = ['red', 'green', 'blue']

plt.figure(figsize=(8, 6))
plt.scatter(x_test['radius_mean'], x_test['texture_mean'], c=y_train, marker= '<' , cmap='inferno', label='Predicciones')
plt.scatter(x_test['radius_mean'], x_test['texture_mean'], c=y_test, cmap='coolwarm', label='Prueba')
plt.xlabel('Radio medio')
plt.ylabel('Textura media')
plt.title('Gráfico de k-NN para Cáncer de Seno')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 # Define tus propios colores como una lista
#       2 colors = ['red', 'green', 'blue']
# ----> 4 plt.figure(figsize=(8, 6))
#       5 plt.scatter(x_test['radius_mean'], x_test['texture_mean'], c=y_train, marker= '<' , cmap='inferno', label='Predicciones')
#       6 plt.scatter(x_test['radius_mean'], x_test['texture_mean'], c=y_test, cmap='coolwarm', label='Prueba')
#
# NameError: name 'plt' is not defined
