# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.svm import SVR     
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
boston = pd.read_csv('boston.csv', header=1)
boston
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
x= boston.iloc[:, 5:6]
y= boston.iloc[:, 13:14]

# %%
plt.scatter(x, y)
plt.show()

# %%
#separamos los datos de entrenamiento y prueba
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.2)

# %%
#Definir el algoritmo del modelo
SVR= SVR(kernel='linear', C=1.0, epsilon=0.2)

# %%
#Entrenamos el modelo
SVR.fit(x_train, y_train)
# Out:
# c:\Users\josel\OneDrive\Escritorio\Cursos\Python\Analisis de datos\datos\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(epsilon=0.2, kernel='linear')

# %%
y_pred = SVR.predict(x_test)
df_pred = pd.DataFrame(y_pred, columns=['PREDICCION'])
df_pred, y_test
# Out:
# (     PREDICCION
#  0     14.401951
#  1     24.940240
#  2     21.167385
#  3     23.728520
#  4     18.890821
#  ..          ...
#  97    16.054296
#  98    15.696288
#  99    29.401571
#  100   28.731453
#  101   18.854102
#
#  [102 rows x 1 columns],
#       MEDV
#  389  11.5
#  272  24.4
#  358  22.7
#  441  17.1
#  124  18.8
#  ..    ...
#  20   13.6
#  404   8.5
#  40   34.9
#  190  37.0
#  372  50.0
#
#  [102 rows x 1 columns])

# %%
plt.scatter(x_test, y_test)
plt.plot(x_test, y_pred, c= 'r', linewidth= 2)
plt.show()

# %%
print(f'y= {SVR.coef_}x + {SVR.intercept_}')
# Out:
# y= [[9.17969385]]x + [-35.07659885]

# %%
SVR.score(x_train, y_train)
# Out:
# 0.5040131859557272
