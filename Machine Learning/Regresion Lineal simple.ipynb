# %%
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
boston = pd.read_csv('boston.csv', header=1)
boston
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
print(boston.describe())
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
x = pd.DataFrame(boston['RM'])
y = pd.DataFrame(boston['MEDV'])

# %%
plt.scatter(x, y , c= 'b')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Separamos el modelo en entrenamiento y prueba para el algoritmo
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.2)

# %%
#Definimos el modelo a entrenar
lineal_regression= linear_model.LinearRegression()

# %%
#Entrenamos el modelo
lineal_regression.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#Realizamos la prediccion del modelo
pred= lineal_regression.predict(x_test)

df_pred = pd.DataFrame(pred, columns=['PREDICCION'])

# Concatena los DataFrames x y df_pred
conjunto_x = pd.concat([y, df_pred], axis=1)

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Imprime el conjunto resultante
print(conjunto_x)
# Out:
#      MEDV  PREDICCION
# 0    24.0   18.174633
# 1    21.6   11.329191
# 2    34.7   12.143291
# 3    33.4   18.218402
# 4    36.2   16.520172
# 5    28.7   23.847071
# 6    22.9   21.413525
# 7    27.1   26.928395
# 8    16.5   14.935741
# 9    18.9   21.080882
# 10   15.0   26.175572
# 11   18.9   41.074475
# 12   21.7   15.425952
# 13   20.4   24.092176
# 14   18.2   18.769889
# 15   19.9   21.089636
# 16   23.1   21.028360
# 17   17.5   19.575235
# 18   20.2   20.135476
# 19   18.2   22.726590
# 20   13.6   25.492778
# 21   19.6   24.118438
# 22   15.2   21.404771
# 23   14.5   21.772429
# 24   15.6   18.787397
# 25   13.9   32.443265
# 26   16.6   19.759064
# 27   14.8   21.772429
# 28   18.4   28.617871
# 29   21.0   17.509347
# 30   12.7   25.151382
# 31   14.5   21.325988
# 32   13.2   23.768287
# 33   13.1   16.555187
# 34   13.5   24.372297
# 35   18.9   21.194681
# 36   20.0   19.951647
# 37   21.0   15.977439
# 38   24.7   14.384254
# 39   30.8   17.973297
# ...

# %%
plt.scatter(x_test, y_test)
plt.plot(x_test, pred, color= 'r', linewidth= 3)
plt.show()

# %%
#valore del coeficiente
lineal_regression.coef_
#valor del intercepto
lineal_regression.intercept_
print(f'y= {lineal_regression.coef_}x + {lineal_regression.intercept_}')
# Out:
# y= [[8.75376195]]x + [-32.43961828]

# %%
#precision 
lineal_regression.score(x_train, y_train)
#entre mas se acerca a cero peor es el modelo y si se acerca a 1 su ajuste es preciso
# Out:
# 0.46259520040429847
