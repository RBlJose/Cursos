# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style='darkgrid')
df= sns.load_dataset('tips')
print(df)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# factores q afectan a que cambien las propinas en un restaurante (sexo, fumador, clima, tipo de comida)
#sexo
promedio_total_bill = df.groupby('sex')['total_bill'].mean()
promedio_tip = df.groupby('sex')['tip'].mean()
promedio_size = df.groupby('sex')['size'].mean()
print(promedio_total_bill)
print(promedio_tip)
print(promedio_size)

sns.pairplot(df, hue='sex')
plt.show()
#los hombres son los que mas gastan a comparacion de una mesa de mujeres y dato el caso por ende son los q mayor
#propinan dejan, por otro lado los hombres vienen a comer en grupo de dos a cuatro personas por grupo por otro lado
# las mujeres entran en grupo de dos personas a menudo a nuestro restaurante
# Out:
# C:\Users\josel\AppData\Local\Temp\ipykernel_13216\2572400666.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   promedio_total_bill = df.groupby('sex')['total_bill'].mean()
# C:\Users\josel\AppData\Local\Temp\ipykernel_13216\2572400666.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   promedio_tip = df.groupby('sex')['tip'].mean()
# C:\Users\josel\AppData\Local\Temp\ipykernel_13216\2572400666.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   promedio_size = df.groupby('sex')['size'].mean()
# sex
# Male      20.744076
# Female    18.056897
# Name: total_bill, dtype: float64
# sex
# Male      3.089618
# Female    2.833448
# Name: tip, dtype: float64
# sex
# Male      2.630573
# Female    2.459770
# Name: size, dtype: float64

# %%
#fumador
promedio_total_bill = df.groupby('smoker')['total_bill'].mean()
promedio_tip = df.groupby('smoker')['tip'].mean()
promedio_size = df.groupby('smoker')['size'].mean()
print(promedio_total_bill)
print(promedio_tip)
print(promedio_size)
sns.pairplot(df, hue='smoker')
plt.show()
#Los no fumadores consumen y dejan mas propinas q los fumadores
# Out:
# C:\Users\josel\AppData\Local\Temp\ipykernel_13216\1662345742.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   promedio_total_bill = df.groupby('smoker')['total_bill'].mean()
# C:\Users\josel\AppData\Local\Temp\ipykernel_13216\1662345742.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   promedio_tip = df.groupby('smoker')['tip'].mean()
# C:\Users\josel\AppData\Local\Temp\ipykernel_13216\1662345742.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   promedio_size = df.groupby('smoker')['size'].mean()
# smoker
# Yes    20.756344
# No     19.188278
# Name: total_bill, dtype: float64
# smoker
# Yes    3.008710
# No     2.991854
# Name: tip, dtype: float64
# smoker
# Yes    2.408602
# No     2.668874
# Name: size, dtype: float64

# %%
#dia
promedio_total_bill = df.groupby('day')['total_bill'].mean()
promedio_tip = df.groupby('day')['tip'].mean()
promedio_size = df.groupby('day')['size'].mean()
print(promedio_total_bill)
print(promedio_tip)
print(promedio_size)
sns.pairplot(df, hue='day')
plt.show()
#los dias jueves sabado y domingo son los dias q mas se consumen, por el contrario el dia viernes el tamaño 
#de la cuenta de los clientes es baja y por ende las propinas son pequeñas, dado que este dia las pesonas por mesa
#son a los mucho de dos personas
# Out:
# C:\Users\josel\AppData\Local\Temp\ipykernel_13216\2647860754.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   promedio_total_bill = df.groupby('day')['total_bill'].mean()
# C:\Users\josel\AppData\Local\Temp\ipykernel_13216\2647860754.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   promedio_tip = df.groupby('day')['tip'].mean()
# C:\Users\josel\AppData\Local\Temp\ipykernel_13216\2647860754.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   promedio_size = df.groupby('day')['size'].mean()
# day
# Thur    17.682742
# Fri     17.151579
# Sat     20.441379
# Sun     21.410000
# Name: total_bill, dtype: float64
# day
# Thur    2.771452
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Name: tip, dtype: float64
# day
# Thur    2.451613
# Fri     2.105263
# Sat     2.517241
# Sun     2.842105
# Name: size, dtype: float64

# %%
#tipo de comida
promedio_total_bill = df.groupby('time')['total_bill'].mean()
promedio_tip = df.groupby('time')['tip'].mean()
promedio_size = df.groupby('time')['size'].mean()
print(promedio_total_bill)
print(promedio_tip)
print(promedio_size)
sns.pairplot(df, hue='time')
plt.show()
#El ser el desayuno la primera comida y dato en los menus el precio de es mucho menor a comparacion de un almuerzon q
#son platos fuertes y mas costosos se obtienen mayor ganancia de los mismo y por ende dejan una mayor propina por ello
# Out:
# C:\Users\josel\AppData\Local\Temp\ipykernel_13216\345956853.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   promedio_total_bill = df.groupby('time')['total_bill'].mean()
# C:\Users\josel\AppData\Local\Temp\ipykernel_13216\345956853.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   promedio_tip = df.groupby('time')['tip'].mean()
# C:\Users\josel\AppData\Local\Temp\ipykernel_13216\345956853.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   promedio_size = df.groupby('time')['size'].mean()
# time
# Lunch     17.168676
# Dinner    20.797159
# Name: total_bill, dtype: float64
# time
# Lunch     2.728088
# Dinner    3.102670
# Name: tip, dtype: float64
# time
# Lunch     2.411765
# Dinner    2.630682
# Name: size, dtype: float64

# %%
df['tip_porcentage']= (df['tip']/df['total_bill'])*100
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  tip_porcentage
# 0         16.99  1.01  Female     No   Sun  Dinner     2        5.944673
# 1         10.34  1.66    Male     No   Sun  Dinner     3       16.054159
# 2         21.01  3.50    Male     No   Sun  Dinner     3       16.658734
# 3         23.68  3.31    Male     No   Sun  Dinner     2       13.978041
# 4         24.59  3.61  Female     No   Sun  Dinner     4       14.680765
# ..          ...   ...     ...    ...   ...     ...   ...             ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3       20.392697
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2        7.358352
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2        8.822232
# 242       17.82  1.75    Male     No   Sat  Dinner     2        9.820426
# 243       18.78  3.00  Female     No  Thur  Dinner     2       15.974441
#
# [244 rows x 8 columns]

# %%
sns.barplot(data =df, x='sex', y='tip_porcentage', errorbar=None, palette= ["skyblue", "salmon"])
# Out:
# C:\Users\josel\AppData\Local\Temp\ipykernel_13216\3355058041.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data =df, x='sex', y='tip_porcentage', errorbar=None, palette= ["skyblue", "salmon"])
# <Axes: xlabel='sex', ylabel='tip_porcentage'>
